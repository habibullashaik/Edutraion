# %%
#import necessary libraries 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris_data = pd.read_csv('IRIS.csv')
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
Label_Encoder = LabelEncoder()
iris_data ['species_emcod'] = Label_Encoder.fit_transform(iris_data['species'])

# %%
x_col = iris_data[['sepal_length',	'sepal_width',	'petal_length','petal_width']]
y_col = iris_data['species']

# %%
#Now for training the model just split the dataset into 80% and 20% for traing and testing
x_train,x_test,y_train,y_test=train_test_split(x_col,y_col,test_size = 0.2,random_state =42)

# %%
iris_model = LogisticRegression(max_iter = 200)
iris_model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
#Prediction and Evaluation
y_prediction = iris_model.predict(x_test)
accuracy = accuracy_score(y_test,y_prediction)
confusion_mat = confusion_matrix(y_test,y_prediction)
report_iris = classification_report(y_test,y_prediction,target_names = Label_Encoder.classes_)

# %%
plt.figure(figsize = (6,4))
sns.heatmap(confusion_mat,annot = True,fmt = 'd',cmap = 'Blues',xticklabels = Label_Encoder.classes_,yticklabels = Label_Encoder.classes_)
plt.xlabel("model_prediction")
plt.ylabel("Actual")
plt.title("Confusion_Matrix")
plt.tight_layout()
plt.show()
# Out:
# '                 precision    recall  f1-score   support\n\n    Iris-setosa       1.00      1.00      1.00        10\nIris-versicolor       1.00      1.00      1.00         9\n Iris-virginica       1.00      1.00      1.00        11\n\n       accuracy                           1.00        30\n      macro avg       1.00      1.00      1.00        30\n   weighted avg       1.00      1.00      1.00        30\n'

# %%
accuracy
# Out:
# 1.0

# %%
print(report_iris)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
